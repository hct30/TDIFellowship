# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
#! Data with column information
dfC = pd.read_csv('sjbrande_ngl_db.csv')
dfC = dfC[np.abs(dfC['Size']-dfC['Size'].mean()) <= (4*dfC['Size'].std())]
print(df.head())
# Out:
#    Table  TypeC     Column  ... Rows  TypeT                          CommentsT
# 1   BORH  Table   BORH_DIA  ...  430  Table  General information for boreholes
# 2   BORH  Table  BORH_ENDD  ...  430  Table  General information for boreholes
# 3   BORH  Table    BORH_ID  ...  430  Table  General information for boreholes
# 8   BORH  Table  BORH_STAR  ...  430  Table  General information for boreholes
# 10  BORH  Table    TEST_ID  ...  430  Table  General information for boreholes
#
# [5 rows x 10 columns]

# %%
fig = px.sunburst(dfC, path=["Table", "Column"], values="Size", hover_data=["Comments"])
fig.show()

# %%
#! Data with table name and #rows in each table.
dfT = pd.read_csv('sjbrande_ngl_db_table.csv')
dfT = dfT.rename(columns={'Table / View': 'Table'})
print(dfT.columns)
# Out:
# Index(['Table', 'Children', 'Parents', 'Columns', 'Rows', 'Type', 'Comments'], dtype='object')

# %%
#! Merge the dataframe to get information on the size of table
df = pd.merge(dfC, dfT,  how="inner", on='Table', suffixes=("C", "T"))
#! Delete unnecessary columns
for col in ['Nullable','Auto','Default','Children','Parents']: del df[col]
print(df.columns)
# Out:
# Index(['Table', 'TypeC', 'Column', 'DataType', 'Size', 'CommentsC', 'Columns',
#        'Rows', 'TypeT', 'CommentsT'],
#       dtype='object')

# %%
#! Filter only data required for analysis
df = df[df['DataType'] != 'VARCHAR']
#! Plot
fig = px.scatter(df, x="Column", y="Table",
	         size="Rows", color="DataType",
                 hover_name="CommentsC", size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5189c864-a8d7-44d8-84e0-4ca238972667" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5189c864-a8d7-44d8-84e0-4ca238972667")) {
#                     Plotly.newPlot(
#                         '5189c864-a8d7-44d8-84e0-4ca238972667',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>DataType=FLOAT<br>Column=%{x}<br>Table=%{y}<br>Rows=%{marker.size}", "hovertext": ["Borehole diameter in m", "Consolidation displacement in cm", "Consolidation time in seCOND2s", "Final effective vertical stress", "Diameter of the consolidation specimen (cm)", "Initial void ratio of the consolidation specimen", "Initial height of the consolidation specimen (cm)", "Initial saturation of the consolidation specimen (%)", "Initial water content of the consolidation specimen (%)", "Specific depth for within-layer description in m", "Vertical Strain in percent", "Vertical Stress in kPa", "Shear Stress in kPa", "Time in sec", "Shear Strain in percent", "Vertical Strain in percent", "Vertical Stress in kPa", "Shear Stress 1 in kPa", "Shear Stress 2 in kPa", "Time in sec", "Shear Strain 1 in percent", "Shear Strain 2 in percent", "Specimen diameter in cm", "Initial void ratio", "Specimen initial height in cm", "Initial water content", "Average Dip (deg)", "Earthquake Magnitude", "Seismic Moment Mo (dyne.cm)", "Average Rake (deg)", "Average Strike (deg)", "Hypocenter Depth (km)", "Magnitude Uncertainty: Kagan Model", "Magnitude Uncertainty: Statistical", "Source to Site Azimuth (deg) - Used to assess HW/FW locations", "Closest distance from the recording site to the ruptured fault area (km)", "Epicentral distance (km)", "Hypocentral distance (km)", "Campbell Distance, R (km)", "Joyner and Boore (1981) Distance (km)", "Root-mean-squared distance (km)", "Horizontal distance (km) from top edge of rupture. Measured perpendicular to the fault strike (km)", "Peak Ground Acceleration (g)", "Peak Ground Displacement (m)", "Peak Ground Velocity (cm/s)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.01 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.02 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.022 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.025 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.029 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.030 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.032 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.035 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.036 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.040 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.042 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.044 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.045 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.046 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.048 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.050 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.055 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.060 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.065 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.067 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.070 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.075 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.080 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.085 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.090 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.095 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.100 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.110 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.120 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.130 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.133 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.140 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.150 s (g)", "5%-Damped Pseudo Spectral Acceleration at Period T=0.160 ...
